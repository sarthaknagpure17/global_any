# %%
import  pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel("../Datasets/WIID_19Dec2018.xlsx")

# %%
df
# Out:
#           id      country   c3  c2  year  gini_reported    q1     q2     q3  \
# 0          1  Afghanistan  AFG  AF  2008          29.00  9.00  13.00  17.00
# 1          2      Albania  ALB  AL  1996          27.01  9.15  13.70  17.73
# 2          3      Albania  ALB  AL  2002          31.74  8.35  12.58  16.49
# 3          4      Albania  ALB  AL  2005          30.60  8.40  12.90  17.03
# 4          5      Albania  ALB  AL  2008          29.98  8.87  13.07  16.83
# ...      ...          ...  ...  ..   ...            ...   ...    ...    ...
# 11096  11097     Zimbabwe  ZWE  ZW  1995          70.30  1.58   3.64   6.34
# 11097  11098     Zimbabwe  ZWE  ZW  2011          42.30   NaN    NaN    NaN
# 11098  11099     Zimbabwe  ZWE  ZW  2011          37.00   NaN    NaN    NaN
# 11099  11100     Zimbabwe  ZWE  ZW  2011          39.00   NaN    NaN    NaN
# 11100  11101     Zimbabwe  ZWE  ZW  2011          43.15  5.83   9.50  14.01
#
#           q4  ...  median_usd  gdp_ppp_pc_usd2011  population  revision  \
# 0      22.00  ...         NaN              1298.0  27294031.0  New 2013
# 1      23.29  ...      1982.0              4812.0   3092228.0  New 2018
# 2      22.21  ...      1902.0              6316.0   3119029.0  New 2018
# 3      22.50  ...      2217.0              7563.0   3079179.0  New 2018
# 4      22.23  ...      2385.0              9018.0   2991651.0  New 2018
# ...      ...  ...         ...                 ...         ...       ...
# 11096  11.08  ...         NaN              2488.0  11320346.0       NaN
# 11097    NaN  ...         NaN              1667.0  14386649.0  New 2013
# 11098    NaN  ...         NaN              1667.0  14386649.0  New 2013
# 11099    NaN  ...         NaN              1667.0  14386649.0  New 2013
# 11100  21.01  ...      1230.0              1667.0  14386649.0  New 2018
#
#        quality  quality_score                          source  \
# 0         High             12  National statistical authority
# 1      Average             13                      World Bank
# 2      Average             13                      World Bank
# 3      Average             13                      World Bank
# 4      Average             13                      World Bank
# ...        ...            ...                             ...
# 11096      Low             13                      World Bank
# 11097     High             11  National statistical authority
# 11098     High             11  National statistical authority
# 11099     High             11  National statistical authority
# 11100  Average             13                      World Bank
#
#                                          source_detailed  \
# 0      European Commission and the Government of Afgh...
# 1                                        World Bank 2018
# 2                                        World Bank 2018
# 3                                        World Bank 2018
# 4                                        World Bank 2018
# ...                                                  ...
# 11096              Deininger and Squire, World Bank 2004
# 11097           Zimbabwe National Statistics Agency 2011
# 11098           Zimbabwe National Statistics Agency 2011
# 11099           Zimbabwe National Statistics Agency 2011
# 11100                                    World Bank 2018
#
#                                   source_comments  \
# 0      National Risk and Vulnerability Assessment
# 1                                       PovcalNet
# 2                                       PovcalNet
# 3                                       PovcalNet
# 4                                       PovcalNet
# ...                                           ...
# 11096                     World Bank. Compilation
# 11097             Zimbabwe Poverty Profile Report
# 11098             Zimbabwe Poverty Profile Report
# 11099             Zimbabwe Poverty Profile Report
# 11100                                   PovcalNet
#
#                                                   survey
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11096         Income, Consumption and Expenditure Survey
# 11097  Poverty Income Consumption and Expenditure Sur...
# 11098  Poverty Income Consumption and Expenditure Sur...
# 11099  Poverty Income Consumption and Expenditure Sur...
# 11100                                                NaN
#
# [11101 rows x 55 columns]

# %%
df.columns
# Out:
# Index(['id', 'country', 'c3', 'c2', 'year', 'gini_reported', 'q1', 'q2', 'q3',
#        'q4', 'q5', 'd1', 'd2', 'd3', 'd4', 'd5', 'd6', 'd7', 'd8', 'd9', 'd10',
#        'bottom5', 'top5', 'resource', 'resource_detailed', 'scale',
#        'scale_detailed', 'sharing_unit', 'reference_unit', 'areacovr',
#        'areacovr_detailed', 'popcovr', 'popcovr_detailed', 'region_un',
#        'region_un_sub', 'region_wb', 'eu', 'oecd', 'incomegroup', 'mean',
#        'median', 'currency', 'reference_period', 'exchangerate', 'mean_usd',
#        'median_usd', 'gdp_ppp_pc_usd2011', 'population', 'revision', 'quality',
#        'quality_score', 'source', 'source_detailed', 'source_comments',
#        'survey'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                       0
# country                  0
# c3                       0
# c2                       8
# year                     0
# gini_reported           47
# q1                    4004
# q2                    4168
# q3                    4142
# q4                    4136
# q5                    4003
# d1                    4837
# d2                    4843
# d3                    4843
# d4                    4843
# d5                    4823
# d6                    4818
# d7                    4812
# d8                    4815
# d9                    4801
# d10                   4763
# bottom5               9506
# top5                  8922
# resource                 1
# resource_detailed        0
# scale                  505
# scale_detailed         505
# sharing_unit           502
# reference_unit          35
# areacovr                 0
# areacovr_detailed        0
# popcovr                  0
# popcovr_detailed         0
# region_un                0
# region_un_sub            0
# region_wb                0
# eu                       0
# oecd                     0
# incomegroup              0
# mean                  5315
# median                6581
# currency              4389
# reference_period      4325
# exchangerate           966
# mean_usd              9447
# median_usd            9451
# gdp_ppp_pc_usd2011    3409
# population              58
# revision              4457
# quality                  0
# quality_score            0
# source                   0
# source_detailed          0
# source_comments       5562
# survey                7030
# dtype: int64

# %%
df=df.drop(['bottom5','top5','mean_usd','median_usd'],axis=1)

# %%
df
# Out:
#           id      country   c3  c2  year  gini_reported    q1     q2     q3  \
# 0          1  Afghanistan  AFG  AF  2008          29.00  9.00  13.00  17.00
# 1          2      Albania  ALB  AL  1996          27.01  9.15  13.70  17.73
# 2          3      Albania  ALB  AL  2002          31.74  8.35  12.58  16.49
# 3          4      Albania  ALB  AL  2005          30.60  8.40  12.90  17.03
# 4          5      Albania  ALB  AL  2008          29.98  8.87  13.07  16.83
# ...      ...          ...  ...  ..   ...            ...   ...    ...    ...
# 11096  11097     Zimbabwe  ZWE  ZW  1995          70.30  1.58   3.64   6.34
# 11097  11098     Zimbabwe  ZWE  ZW  2011          42.30   NaN    NaN    NaN
# 11098  11099     Zimbabwe  ZWE  ZW  2011          37.00   NaN    NaN    NaN
# 11099  11100     Zimbabwe  ZWE  ZW  2011          39.00   NaN    NaN    NaN
# 11100  11101     Zimbabwe  ZWE  ZW  2011          43.15  5.83   9.50  14.01
#
#           q4  ...  exchangerate  gdp_ppp_pc_usd2011  population  revision  \
# 0      22.00  ...     50.249615              1298.0  27294031.0  New 2013
# 1      23.29  ...    104.498917              4812.0   3092228.0  New 2018
# 2      22.21  ...    140.154516              6316.0   3119029.0  New 2018
# 3      22.50  ...     99.870254              7563.0   3079179.0  New 2018
# 4      22.23  ...     83.894604              9018.0   2991651.0  New 2018
# ...      ...  ...           ...                 ...         ...       ...
# 11096  11.08  ...      0.008675              2488.0  11320346.0       NaN
# 11097    NaN  ...           NaN              1667.0  14386649.0  New 2013
# 11098    NaN  ...           NaN              1667.0  14386649.0  New 2013
# 11099    NaN  ...           NaN              1667.0  14386649.0  New 2013
# 11100  21.01  ...           NaN              1667.0  14386649.0  New 2018
#
#        quality  quality_score                          source  \
# 0         High             12  National statistical authority
# 1      Average             13                      World Bank
# 2      Average             13                      World Bank
# 3      Average             13                      World Bank
# 4      Average             13                      World Bank
# ...        ...            ...                             ...
# 11096      Low             13                      World Bank
# 11097     High             11  National statistical authority
# 11098     High             11  National statistical authority
# 11099     High             11  National statistical authority
# 11100  Average             13                      World Bank
#
#                                          source_detailed  \
# 0      European Commission and the Government of Afgh...
# 1                                        World Bank 2018
# 2                                        World Bank 2018
# 3                                        World Bank 2018
# 4                                        World Bank 2018
# ...                                                  ...
# 11096              Deininger and Squire, World Bank 2004
# 11097           Zimbabwe National Statistics Agency 2011
# 11098           Zimbabwe National Statistics Agency 2011
# 11099           Zimbabwe National Statistics Agency 2011
# 11100                                    World Bank 2018
#
#                                   source_comments  \
# 0      National Risk and Vulnerability Assessment
# 1                                       PovcalNet
# 2                                       PovcalNet
# 3                                       PovcalNet
# 4                                       PovcalNet
# ...                                           ...
# 11096                     World Bank. Compilation
# 11097             Zimbabwe Poverty Profile Report
# 11098             Zimbabwe Poverty Profile Report
# 11099             Zimbabwe Poverty Profile Report
# 11100                                   PovcalNet
#
#                                                   survey
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11096         Income, Consumption and Expenditure Survey
# 11097  Poverty Income Consumption and Expenditure Sur...
# 11098  Poverty Income Consumption and Expenditure Sur...
# 11099  Poverty Income Consumption and Expenditure Sur...
# 11100                                                NaN
#
# [11101 rows x 51 columns]

# %%
df.isnull().sum()
# Out:
# id                       0
# country                  0
# c3                       0
# c2                       8
# year                     0
# gini_reported           47
# q1                    4004
# q2                    4168
# q3                    4142
# q4                    4136
# q5                    4003
# d1                    4837
# d2                    4843
# d3                    4843
# d4                    4843
# d5                    4823
# d6                    4818
# d7                    4812
# d8                    4815
# d9                    4801
# d10                   4763
# resource                 1
# resource_detailed        0
# scale                  505
# scale_detailed         505
# sharing_unit           502
# reference_unit          35
# areacovr                 0
# areacovr_detailed        0
# popcovr                  0
# popcovr_detailed         0
# region_un                0
# region_un_sub            0
# region_wb                0
# eu                       0
# oecd                     0
# incomegroup              0
# mean                  5315
# median                6581
# currency              4389
# reference_period      4325
# exchangerate           966
# gdp_ppp_pc_usd2011    3409
# population              58
# revision              4457
# quality                  0
# quality_score            0
# source                   0
# source_detailed          0
# source_comments       5562
# survey                7030
# dtype: int64

# %%
df=df.drop(['c2'],axis=1)

# %%
df
# Out:
#           id      country   c3  year  gini_reported    q1     q2     q3  \
# 0          1  Afghanistan  AFG  2008          29.00  9.00  13.00  17.00
# 1          2      Albania  ALB  1996          27.01  9.15  13.70  17.73
# 2          3      Albania  ALB  2002          31.74  8.35  12.58  16.49
# 3          4      Albania  ALB  2005          30.60  8.40  12.90  17.03
# 4          5      Albania  ALB  2008          29.98  8.87  13.07  16.83
# ...      ...          ...  ...   ...            ...   ...    ...    ...
# 11096  11097     Zimbabwe  ZWE  1995          70.30  1.58   3.64   6.34
# 11097  11098     Zimbabwe  ZWE  2011          42.30   NaN    NaN    NaN
# 11098  11099     Zimbabwe  ZWE  2011          37.00   NaN    NaN    NaN
# 11099  11100     Zimbabwe  ZWE  2011          39.00   NaN    NaN    NaN
# 11100  11101     Zimbabwe  ZWE  2011          43.15  5.83   9.50  14.01
#
#           q4     q5  ...  exchangerate  gdp_ppp_pc_usd2011  population  \
# 0      22.00  39.00  ...     50.249615              1298.0  27294031.0
# 1      23.29  36.12  ...    104.498917              4812.0   3092228.0
# 2      22.21  40.37  ...    140.154516              6316.0   3119029.0
# 3      22.50  39.17  ...     99.870254              7563.0   3079179.0
# 4      22.23  39.00  ...     83.894604              9018.0   2991651.0
# ...      ...    ...  ...           ...                 ...         ...
# 11096  11.08  77.36  ...      0.008675              2488.0  11320346.0
# 11097    NaN    NaN  ...           NaN              1667.0  14386649.0
# 11098    NaN    NaN  ...           NaN              1667.0  14386649.0
# 11099    NaN    NaN  ...           NaN              1667.0  14386649.0
# 11100  21.01  49.66  ...           NaN              1667.0  14386649.0
#
#        revision  quality  quality_score                          source  \
# 0      New 2013     High             12  National statistical authority
# 1      New 2018  Average             13                      World Bank
# 2      New 2018  Average             13                      World Bank
# 3      New 2018  Average             13                      World Bank
# 4      New 2018  Average             13                      World Bank
# ...         ...      ...            ...                             ...
# 11096       NaN      Low             13                      World Bank
# 11097  New 2013     High             11  National statistical authority
# 11098  New 2013     High             11  National statistical authority
# 11099  New 2013     High             11  National statistical authority
# 11100  New 2018  Average             13                      World Bank
#
#                                          source_detailed  \
# 0      European Commission and the Government of Afgh...
# 1                                        World Bank 2018
# 2                                        World Bank 2018
# 3                                        World Bank 2018
# 4                                        World Bank 2018
# ...                                                  ...
# 11096              Deininger and Squire, World Bank 2004
# 11097           Zimbabwe National Statistics Agency 2011
# 11098           Zimbabwe National Statistics Agency 2011
# 11099           Zimbabwe National Statistics Agency 2011
# 11100                                    World Bank 2018
#
#                                   source_comments  \
# 0      National Risk and Vulnerability Assessment
# 1                                       PovcalNet
# 2                                       PovcalNet
# 3                                       PovcalNet
# 4                                       PovcalNet
# ...                                           ...
# 11096                     World Bank. Compilation
# 11097             Zimbabwe Poverty Profile Report
# 11098             Zimbabwe Poverty Profile Report
# 11099             Zimbabwe Poverty Profile Report
# 11100                                   PovcalNet
#
#                                                   survey
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11096         Income, Consumption and Expenditure Survey
# 11097  Poverty Income Consumption and Expenditure Sur...
# 11098  Poverty Income Consumption and Expenditure Sur...
# 11099  Poverty Income Consumption and Expenditure Sur...
# 11100                                                NaN
#
# [11101 rows x 50 columns]

# %%
df['gini_reported'].unique()
# Out:
# array([29.  , 27.01, 31.74, ..., 74.6 , 70.3 , 43.15])

# %%
df['gini_reported'].value_counts()
# Out:
# gini_reported
# 33.00    68
# 35.00    65
# 32.00    64
# 34.00    62
# 31.00    60
#          ..
# 34.46     1
# 33.69     1
# 34.73     1
# 36.71     1
# 77.30     1
# Name: count, Length: 1774, dtype: int64

# %%
df['c3'].unique()
# Out:
# array(['AFG', 'ALB', 'DZA', 'AND', 'AGO', 'ARG', 'ARM', 'AUS', 'AUT',
#        'AZE', 'BHS', 'BGD', 'BRB', 'BLR', 'BEL', 'BLZ', 'BEN', 'BTN',
#        'BOL', 'BIH', 'BWA', 'BRA', 'BGR', 'BFA', 'BDI', 'KHM', 'CMR',
#        'CAN', 'CPV', 'CAF', 'TCD', 'CHL', 'CHN', 'COL', 'COM', 'COD',
#        'COG', 'CRI', 'CIV', 'HRV', 'CUB', 'CYP', 'CZE', 'CSK', 'DNK',
#        'DJI', 'DMA', 'DOM', 'ECU', 'EGY', 'SLV', 'GNQ', 'ERI', 'EST',
#        'SWZ', 'ETH', 'FJI', 'FIN', 'FRA', 'GAB', 'GMB', 'GEO', 'DEU',
#        'GHA', 'GRC', 'GTM', 'GIN', 'GNB', 'GUY', 'HTI', 'HND', 'HKG',
#        'HUN', 'ISL', 'IND', 'IDN', 'IRN', 'IRQ', 'IRL', 'ISR', 'ITA',
#        'JAM', 'JPN', 'JOR', 'KAZ', 'KEN', 'KIR', 'KOR', 'KSV', 'KGZ',
#        'LAO', 'LVA', 'LBN', 'LSO', 'LBR', 'LTU', 'LUX', 'MKD', 'MDG',
#        'MWI', 'MYS', 'MDV', 'MLI', 'MLT', 'MRT', 'MUS', 'MEX', 'FSM',
#        'MDA', 'MNG', 'MNE', 'MAR', 'MOZ', 'MMR', 'NAM', 'NRU', 'NPL',
#        'NLD', 'NZL', 'NIC', 'NER', 'NGA', 'NOR', 'OMN', 'PAK', 'PLW',
#        'PAN', 'PNG', 'PRY', 'PER', 'PHL', 'POL', 'PRT', 'PRI', 'QAT',
#        'REU', 'ROU', 'RUS', 'RWA', 'LCA', 'WSM', 'STP', 'SAU', 'SEN',
#        'SRB', 'SCG', 'SYC', 'SLE', 'SGP', 'SVK', 'SVN', 'SLB', 'SOM',
#        'ZAF', 'SSD', 'SUN', 'ESP', 'LKA', 'SDN', 'SUR', 'SWE', 'CHE',
#        'SYR', 'TWN', 'TJK', 'TZA', 'THA', 'TLS', 'TGO', 'TON', 'TTO',
#        'TUN', 'TUR', 'TKM', 'TUV', 'UGA', 'UKR', 'GBR', 'USA', 'URY',
#        'UZB', 'VUT', 'VEN', 'VNM', 'WBG', 'YEM', 'YUG', 'ZMB', 'ZWE'],
#       dtype=object)

# %%
df.dropna(subset=['gini_reported'])
df
# Out:
#           id      country   c3  year  gini_reported    q1     q2     q3  \
# 0          1  Afghanistan  AFG  2008          29.00  9.00  13.00  17.00
# 1          2      Albania  ALB  1996          27.01  9.15  13.70  17.73
# 2          3      Albania  ALB  2002          31.74  8.35  12.58  16.49
# 3          4      Albania  ALB  2005          30.60  8.40  12.90  17.03
# 4          5      Albania  ALB  2008          29.98  8.87  13.07  16.83
# ...      ...          ...  ...   ...            ...   ...    ...    ...
# 11096  11097     Zimbabwe  ZWE  1995          70.30  1.58   3.64   6.34
# 11097  11098     Zimbabwe  ZWE  2011          42.30   NaN    NaN    NaN
# 11098  11099     Zimbabwe  ZWE  2011          37.00   NaN    NaN    NaN
# 11099  11100     Zimbabwe  ZWE  2011          39.00   NaN    NaN    NaN
# 11100  11101     Zimbabwe  ZWE  2011          43.15  5.83   9.50  14.01
#
#           q4     q5  ...  exchangerate  gdp_ppp_pc_usd2011  population  \
# 0      22.00  39.00  ...     50.249615              1298.0  27294031.0
# 1      23.29  36.12  ...    104.498917              4812.0   3092228.0
# 2      22.21  40.37  ...    140.154516              6316.0   3119029.0
# 3      22.50  39.17  ...     99.870254              7563.0   3079179.0
# 4      22.23  39.00  ...     83.894604              9018.0   2991651.0
# ...      ...    ...  ...           ...                 ...         ...
# 11096  11.08  77.36  ...      0.008675              2488.0  11320346.0
# 11097    NaN    NaN  ...           NaN              1667.0  14386649.0
# 11098    NaN    NaN  ...           NaN              1667.0  14386649.0
# 11099    NaN    NaN  ...           NaN              1667.0  14386649.0
# 11100  21.01  49.66  ...           NaN              1667.0  14386649.0
#
#        revision  quality  quality_score                          source  \
# 0      New 2013     High             12  National statistical authority
# 1      New 2018  Average             13                      World Bank
# 2      New 2018  Average             13                      World Bank
# 3      New 2018  Average             13                      World Bank
# 4      New 2018  Average             13                      World Bank
# ...         ...      ...            ...                             ...
# 11096       NaN      Low             13                      World Bank
# 11097  New 2013     High             11  National statistical authority
# 11098  New 2013     High             11  National statistical authority
# 11099  New 2013     High             11  National statistical authority
# 11100  New 2018  Average             13                      World Bank
#
#                                          source_detailed  \
# 0      European Commission and the Government of Afgh...
# 1                                        World Bank 2018
# 2                                        World Bank 2018
# 3                                        World Bank 2018
# 4                                        World Bank 2018
# ...                                                  ...
# 11096              Deininger and Squire, World Bank 2004
# 11097           Zimbabwe National Statistics Agency 2011
# 11098           Zimbabwe National Statistics Agency 2011
# 11099           Zimbabwe National Statistics Agency 2011
# 11100                                    World Bank 2018
#
#                                   source_comments  \
# 0      National Risk and Vulnerability Assessment
# 1                                       PovcalNet
# 2                                       PovcalNet
# 3                                       PovcalNet
# 4                                       PovcalNet
# ...                                           ...
# 11096                     World Bank. Compilation
# 11097             Zimbabwe Poverty Profile Report
# 11098             Zimbabwe Poverty Profile Report
# 11099             Zimbabwe Poverty Profile Report
# 11100                                   PovcalNet
#
#                                                   survey
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11096         Income, Consumption and Expenditure Survey
# 11097  Poverty Income Consumption and Expenditure Sur...
# 11098  Poverty Income Consumption and Expenditure Sur...
# 11099  Poverty Income Consumption and Expenditure Sur...
# 11100                                                NaN
#
# [11101 rows x 50 columns]

# %%
df['q1'].unique()
# Out:
# array([ 9.  ,  9.15,  8.35,  8.4 ,  8.87,  8.85,  6.54,  6.96,  9.36,
#          nan,  9.9 ,  3.18,  3.  ,  5.  ,  4.  ,  6.  ,  5.43,  7.4 ,
#         7.5 ,  6.8 ,  6.9 ,  7.  ,  6.1 ,  7.2 ,  5.1 ,  5.2 ,  6.4 ,
#         6.2 ,  6.3 ,  5.6 ,  7.8 ,  5.9 ,  6.5 ,  5.3 ,  5.8 ,  5.5 ,
#         5.11,  4.8 ,  5.4 ,  4.61,  5.7 ,  4.4 ,  4.9 ,  4.1 ,  4.2 ,
#         4.82,  4.6 ,  4.7 ,  4.45,  3.8 ,  4.38,  3.76,  4.5 ,  3.51,
#         4.3 ,  3.9 ,  3.6 ,  3.55,  3.7 ,  3.41,  3.4 ,  3.49,  3.5 ,
#         3.2 ,  3.19,  3.1 ,  2.58,  2.6 ,  2.75,  3.3 ,  2.4 ,  2.8 ,
#         3.64,  3.74,  3.87,  4.04,  4.05,  4.64,  4.94,  5.02,  5.09,
#         4.99,  1.8 ,  4.56,  5.54,  2.69,  6.52,  7.56,  7.73,  8.05,
#         8.66,  7.59,  8.93,  7.6 ,  8.41,  7.9 ,  9.12,  9.37,  8.  ,
#         9.1 ,  9.04,  8.99,  8.62,  8.45,  8.22,  7.86,  6.6 ,  6.73,
#         6.59,  6.57,  6.99,  5.84,  4.77,  7.75,  8.09,  6.58,  7.68,
#         7.92,  6.36,  6.31,  7.48,  7.35,  7.72,  7.27,  7.42,  7.69,
#         6.22,  6.28,  7.57,  7.32,  7.44,  6.13,  7.39,  7.31,  7.51,
#         6.26,  6.14,  7.37,  8.2 ,  7.25,  7.19,  7.23,  7.22,  7.17,
#         6.32,  6.11,  7.28,  8.1 ,  9.73, 10.04,  7.95,  8.57,  8.02,
#         8.16, 10.  ,  8.58,  9.29,  8.48,  8.5 ,  9.24,  9.4 ,  8.56,
#         8.76,  9.6 ,  8.6 ,  7.99,  8.46,  9.5 ,  7.98,  8.7 ,  8.8 ,
#         7.67,  8.08,  8.63,  7.83,  8.68,  8.11,  8.9 ,  8.03,  7.88,
#         7.07,  7.43, 12.86, 12.2 , 13.32, 13.37,  3.05,  3.03,  3.89,
#         3.54,  5.56,  7.7 , 13.4 , 13.7 , 11.4 ,  7.36,  6.64,  9.72,
#         8.04,  9.45,  9.62,  5.79,  8.78,  8.65,  5.26,  5.88,  5.22,
#         5.76,  5.07,  8.64,  4.28,  2.25, 10.48, 11.12, 10.18, 10.4 ,
#         9.42, 10.25, 10.39,  7.87, 10.42,  9.58,  7.61, 10.38, 10.3 ,
#        10.26,  8.28,  8.59,  9.06,  8.81,  9.48,  9.53,  9.33,  9.52,
#         9.64,  9.77, 10.51, 10.34,  9.93, 10.44,  8.24,  6.93,  8.42,
#         8.47,  8.55,  8.44,  8.71,  8.69,  9.2 ,  2.96,  3.09,  2.35,
#         3.35,  2.65,  3.32,  3.21,  6.98,  6.06,  3.24,  6.53,  6.66,
#         7.1 ,  6.68,  5.61,  2.01,  2.  ,  2.1 ,  2.3 ,  2.03,  1.4 ,
#         1.2 ,  1.28,  1.3 ,  3.23,  1.08,  1.9 ,  1.6 ,  1.89,  1.7 ,
#         1.69,  2.2 ,  1.96,  2.5 ,  2.26,  2.9 ,  2.89,  3.17,  3.78,
#         3.44,  3.57,  3.77,  3.88,  3.85,  8.79,  7.46,  3.59,  2.27,
#         2.84,  0.8 ,  1.1 ,  0.2 ,  2.51,  4.42,  3.11,  2.67,  2.82,
#         2.62,  2.61,  2.77,  2.74,  2.91,  2.76,  2.38,  2.48,  2.7 ,
#         2.14,  2.22,  1.99,  2.21,  2.06,  2.99,  2.13,  2.33,  2.29,
#         2.44,  2.42,  2.63,  2.87,  2.92,  3.94,  3.67,  3.02,  3.71,
#         4.33,  4.02,  4.31,  3.42,  3.45,  3.91,  4.53,  4.22,  3.37,
#         3.62,  9.7 ,  9.8 , 11.3 , 10.78, 10.36, 10.46, 11.22, 10.79,
#        10.85, 10.69, 11.23, 11.61, 11.6 , 10.16,  9.88, 10.07,  9.71,
#         9.26, 11.05, 12.03, 10.66, 10.8 , 10.45, 10.63, 10.54,  8.54,
#         8.33,  7.11, 10.22,  6.42,  7.47, 10.12,  7.76,  7.93,  7.55,
#         4.16,  7.06,  8.75,  5.66,  6.51,  6.94,  6.27,  6.16,  5.73,
#         6.01,  0.74,  5.53,  0.84,  5.15,  6.24,  5.77,  5.94,  6.7 ,
#         8.31,  7.94,  5.14,  8.92,  6.86,  5.96,  5.27,  6.87,  7.79,
#         9.05,  6.17,  5.83,  4.51,  6.63,  7.13,  7.16,  6.84,  5.58,
#         6.75,  6.45,  7.3 ,  7.82,  6.55,  6.83,  7.41,  6.37,  8.13,
#         7.77,  8.27,  6.67,  7.71,  7.64,  8.17,  6.56,  7.63,  7.34,
#         6.29,  7.38,  7.04,  5.99,  7.15,  7.01,  6.12,  7.12,  6.91,
#         7.29,  7.53,  6.65,  5.75,  4.15,  4.97, 13.5 ,  3.33, 12.  ,
#         4.86,  3.34,  3.36,  4.36,  3.95,  3.46,  3.84,  4.11,  3.65,
#         3.68,  4.03,  3.83,  4.01,  4.37,  4.68,  4.54,  4.87,  4.59,
#         4.88,  5.18,  4.72,  4.75,  9.79,  9.46, 12.37, 11.33,  8.97,
#         8.3 ,  8.18,  5.86,  7.78,  8.06,  4.74,  5.44,  7.49,  4.55,
#         7.85,  7.26,  7.03,  6.72,  8.43,  7.24,  6.44,  8.84,  6.81,
#         5.23,  5.13,  5.71,  6.97,  5.06,  7.14,  4.27,  4.92,  7.65,
#         4.34,  5.04,  4.23,  3.52,  3.61,  2.31,  3.48,  3.27,  2.43,
#         2.36,  2.93,  2.04,  2.39,  3.13,  3.01,  3.43,  2.79,  3.31,
#         3.53,  2.19,  2.55,  3.06,  3.47,  3.12,  3.16,  3.79,  3.86,
#         4.47,  5.69,  4.29,  5.21,  3.22,  3.96,  3.98,  3.99,  4.21,
#         3.93,  4.25,  4.95,  6.89,  5.98,  6.35,  5.31, 10.31, 11.1 ,
#         7.08,  9.23,  6.95,  7.96,  6.88,  7.09,  8.94,  8.74,  8.61,
#         8.39, 11.9 , 12.05, 12.11, 11.66, 11.62, 11.17, 11.69, 11.2 ,
#        10.43, 10.5 , 11.34,  9.83,  9.98,  9.13,  8.77, 10.99, 10.94,
#        10.91, 10.53, 10.73, 10.11, 10.58, 10.71,  9.09,  8.37, 10.1 ,
#         9.32,  9.84,  9.74,  9.63, 10.2 ,  9.38,  9.35,  9.57,  9.34,
#         9.78,  8.73,  9.67, 10.9 , 12.63, 10.86,  7.54, 10.67,  9.41,
#         9.08,  9.82, 10.15,  9.95,  9.85,  9.86,  9.81,  9.22,  8.53,
#         9.31,  5.32,  4.19,  3.92,  3.97,  4.78,  3.73,  3.82,  3.26,
#         3.63,  4.62,  4.71,  4.76,  5.12,  3.28,  4.44,  2.86,  3.69,
#         2.59,  4.12,  4.81,  4.57,  4.69,  8.72,  8.98,  9.17,  9.47,
#         2.88,  5.41,  3.72,  3.08,  2.83,  5.19,  4.63,  5.59,  5.72,
#         7.02,  6.41,  8.07,  7.21,  6.15,  7.97,  2.54,  6.34,  5.52,
#         6.62,  6.69,  7.52, 10.7 , 10.6 , 10.21, 10.76,  8.96, 10.84,
#        10.68, 10.65, 10.88, 11.5 , 10.98, 10.89,  9.3 , 10.77, 11.  ,
#        10.09,  9.55,  8.25,  9.44,  9.39,  8.14,  9.25,  9.21,  9.28,
#         9.18,  6.78,  7.45,  7.74,  8.52,  8.12,  7.81,  7.89,  5.82,
#         6.05,  1.15,  1.09,  1.17,  6.25,  5.37,  5.57,  5.35,  5.81,
#         6.77,  9.65,  8.89,  8.86,  7.84,  9.07,  8.38,  8.15, 11.03,
#         8.23, 10.59,  8.51,  9.89,  8.83,  8.19,  9.92,  7.18,  9.03,
#         7.05,  6.92,  8.29,  8.67,  8.34,  6.85,  6.74,  5.24,  6.19,
#         6.82,  6.61,  5.74,  5.92,  5.95,  5.85,  2.53,  2.15,  2.07,
#         3.25,  6.08,  4.91,  5.38,  1.42,  3.04,  5.62,  4.49,  4.52,
#         1.98,  2.46,  2.78,  4.06,  2.57,  2.81,  2.95,  2.98,  2.32,
#         2.34,  2.12,  2.73,  4.89, 12.3 , 11.42, 11.35, 10.37, 11.58,
#        10.62,  7.33,  9.91,  9.01, 10.06,  9.56,  9.51,  9.11,  8.01,
#         7.62,  9.14,  9.54,  9.27,  7.66, 10.01, 10.13, 10.47, 10.35,
#         9.68,  6.33,  6.21,  4.73,  5.16,  5.28,  6.79,  5.67,  6.49,
#         8.26,  6.38,  7.91,  5.65,  6.39,  4.83,  5.05,  4.96,  4.65,
#         4.18,  4.66,  4.84,  6.46,  6.76,  5.87,  5.34,  6.43,  2.37,
#         6.18,  1.88,  5.46,  5.68,  6.07,  5.48,  5.97,  9.43,  3.39,
#         2.18,  8.36,  3.56,  6.47,  8.82,  9.69, 10.57,  1.75,  4.98,
#         0.73,  9.66,  9.61, 10.02,  9.49, 10.05,  8.91,  1.23,  1.51,
#         6.03, 10.28, 10.41,  9.19,  4.48,  4.39,  4.09,  1.52,  6.09,
#         0.7 ,  0.35,  0.58,  3.38,  0.89,  7.58,  4.17,  4.46,  9.96,
#         8.49,  5.55,  5.42,  5.63, 11.06, 11.98,  1.48,  8.32, 10.24,
#         6.02,  5.78,  4.58,  5.33,  5.29,  3.66,  4.41, 10.08,  9.16,
#        12.8 , 12.9 , 13.9 , 11.7 , 12.4 , 14.6 ,  8.21,  9.02,  4.85,
#         1.79,  2.16,  1.66,  1.64,  1.92,  2.47,  2.52,  3.29,  2.17,
#         2.64,  2.85,  2.45,  1.73,  1.85,  3.14,  5.89,  6.23,  5.17,
#         5.03, 10.03, 12.7 ,  8.95,  6.04,  2.68, 13.6 ,  9.97,  8.88,
#         6.48,  5.64,  1.07,  5.08, 11.89, 11.52, 11.96, 10.87, 11.04,
#        12.6 , 11.01, 12.55, 12.1 , 10.82, 10.92, 10.61,  9.87, 10.49,
#        10.93,  9.99, 10.19, 10.23,  2.66,  1.47,  1.27,  1.71,  1.84,
#         1.41,  1.87,  1.54,  0.3 ,  2.41,  5.39, 10.17,  4.93,  5.91,
#         2.24,  1.94,  5.51,  5.36, 10.56, 10.27, 10.14,  9.76,  9.94,
#        10.32,  9.75,  6.71,  5.49,  5.47,  4.14,  5.01,  2.23,  1.55,
#        10.33, 12.5 ,  0.55,  0.94,  1.86,  3.81,  0.69,  1.58])

# %%
df.q1.dtypes
# Out:
# dtype('float64')

# %%
df.q2.dtypes
# Out:
# dtype('float64')

# %%
df.q3.dtypes
# Out:
# dtype('float64')

# %%
df.q4.dtypes
# Out:
# dtype('float64')

# %%
df.q5.dtypes
# Out:
# dtype('float64')

# %%
quintiles=['q1','q2','q3','q4','q5']
for col in quintiles:
    df[col].fillna(df[col].median(),inplace=True)
df
# Out:
#           id      country   c3  year  gini_reported    q1     q2     q3  \
# 0          1  Afghanistan  AFG  2008          29.00  9.00  13.00  17.00
# 1          2      Albania  ALB  1996          27.01  9.15  13.70  17.73
# 2          3      Albania  ALB  2002          31.74  8.35  12.58  16.49
# 3          4      Albania  ALB  2005          30.60  8.40  12.90  17.03
# 4          5      Albania  ALB  2008          29.98  8.87  13.07  16.83
# ...      ...          ...  ...   ...            ...   ...    ...    ...
# 11096  11097     Zimbabwe  ZWE  1995          70.30  1.58   3.64   6.34
# 11097  11098     Zimbabwe  ZWE  2011          42.30  6.13  11.00  15.72
# 11098  11099     Zimbabwe  ZWE  2011          37.00  6.13  11.00  15.72
# 11099  11100     Zimbabwe  ZWE  2011          39.00  6.13  11.00  15.72
# 11100  11101     Zimbabwe  ZWE  2011          43.15  5.83   9.50  14.01
#
#           q4     q5  ...  exchangerate  gdp_ppp_pc_usd2011  population  \
# 0      22.00  39.00  ...     50.249615              1298.0  27294031.0
# 1      23.29  36.12  ...    104.498917              4812.0   3092228.0
# 2      22.21  40.37  ...    140.154516              6316.0   3119029.0
# 3      22.50  39.17  ...     99.870254              7563.0   3079179.0
# 4      22.23  39.00  ...     83.894604              9018.0   2991651.0
# ...      ...    ...  ...           ...                 ...         ...
# 11096  11.08  77.36  ...      0.008675              2488.0  11320346.0
# 11097  22.06  44.50  ...           NaN              1667.0  14386649.0
# 11098  22.06  44.50  ...           NaN              1667.0  14386649.0
# 11099  22.06  44.50  ...           NaN              1667.0  14386649.0
# 11100  21.01  49.66  ...           NaN              1667.0  14386649.0
#
#        revision  quality  quality_score                          source  \
# 0      New 2013     High             12  National statistical authority
# 1      New 2018  Average             13                      World Bank
# 2      New 2018  Average             13                      World Bank
# 3      New 2018  Average             13                      World Bank
# 4      New 2018  Average             13                      World Bank
# ...         ...      ...            ...                             ...
# 11096       NaN      Low             13                      World Bank
# 11097  New 2013     High             11  National statistical authority
# 11098  New 2013     High             11  National statistical authority
# 11099  New 2013     High             11  National statistical authority
# 11100  New 2018  Average             13                      World Bank
#
#                                          source_detailed  \
# 0      European Commission and the Government of Afgh...
# 1                                        World Bank 2018
# 2                                        World Bank 2018
# 3                                        World Bank 2018
# 4                                        World Bank 2018
# ...                                                  ...
# 11096              Deininger and Squire, World Bank 2004
# 11097           Zimbabwe National Statistics Agency 2011
# 11098           Zimbabwe National Statistics Agency 2011
# 11099           Zimbabwe National Statistics Agency 2011
# 11100                                    World Bank 2018
#
#                                   source_comments  \
# 0      National Risk and Vulnerability Assessment
# 1                                       PovcalNet
# 2                                       PovcalNet
# 3                                       PovcalNet
# 4                                       PovcalNet
# ...                                           ...
# 11096                     World Bank. Compilation
# 11097             Zimbabwe Poverty Profile Report
# 11098             Zimbabwe Poverty Profile Report
# 11099             Zimbabwe Poverty Profile Report
# 11100                                   PovcalNet
#
#                                                   survey
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11096         Income, Consumption and Expenditure Survey
# 11097  Poverty Income Consumption and Expenditure Sur...
# 11098  Poverty Income Consumption and Expenditure Sur...
# 11099  Poverty Income Consumption and Expenditure Sur...
# 11100                                                NaN
#
# [11101 rows x 50 columns]

# %%
df.loc[:,'sharing_unit']=df['sharing_unit'].fillna(df['sharing_unit'].mode()[0])
df
# Out:
#           id      country   c3  year  gini_reported    q1     q2     q3  \
# 0          1  Afghanistan  AFG  2008          29.00  9.00  13.00  17.00
# 1          2      Albania  ALB  1996          27.01  9.15  13.70  17.73
# 2          3      Albania  ALB  2002          31.74  8.35  12.58  16.49
# 3          4      Albania  ALB  2005          30.60  8.40  12.90  17.03
# 4          5      Albania  ALB  2008          29.98  8.87  13.07  16.83
# ...      ...          ...  ...   ...            ...   ...    ...    ...
# 11096  11097     Zimbabwe  ZWE  1995          70.30  1.58   3.64   6.34
# 11097  11098     Zimbabwe  ZWE  2011          42.30  6.13  11.00  15.72
# 11098  11099     Zimbabwe  ZWE  2011          37.00  6.13  11.00  15.72
# 11099  11100     Zimbabwe  ZWE  2011          39.00  6.13  11.00  15.72
# 11100  11101     Zimbabwe  ZWE  2011          43.15  5.83   9.50  14.01
#
#           q4     q5  ...  exchangerate  gdp_ppp_pc_usd2011  population  \
# 0      22.00  39.00  ...     50.249615              1298.0  27294031.0
# 1      23.29  36.12  ...    104.498917              4812.0   3092228.0
# 2      22.21  40.37  ...    140.154516              6316.0   3119029.0
# 3      22.50  39.17  ...     99.870254              7563.0   3079179.0
# 4      22.23  39.00  ...     83.894604              9018.0   2991651.0
# ...      ...    ...  ...           ...                 ...         ...
# 11096  11.08  77.36  ...      0.008675              2488.0  11320346.0
# 11097  22.06  44.50  ...           NaN              1667.0  14386649.0
# 11098  22.06  44.50  ...           NaN              1667.0  14386649.0
# 11099  22.06  44.50  ...           NaN              1667.0  14386649.0
# 11100  21.01  49.66  ...           NaN              1667.0  14386649.0
#
#        revision  quality  quality_score                          source  \
# 0      New 2013     High             12  National statistical authority
# 1      New 2018  Average             13                      World Bank
# 2      New 2018  Average             13                      World Bank
# 3      New 2018  Average             13                      World Bank
# 4      New 2018  Average             13                      World Bank
# ...         ...      ...            ...                             ...
# 11096       NaN      Low             13                      World Bank
# 11097  New 2013     High             11  National statistical authority
# 11098  New 2013     High             11  National statistical authority
# 11099  New 2013     High             11  National statistical authority
# 11100  New 2018  Average             13                      World Bank
#
#                                          source_detailed  \
# 0      European Commission and the Government of Afgh...
# 1                                        World Bank 2018
# 2                                        World Bank 2018
# 3                                        World Bank 2018
# 4                                        World Bank 2018
# ...                                                  ...
# 11096              Deininger and Squire, World Bank 2004
# 11097           Zimbabwe National Statistics Agency 2011
# 11098           Zimbabwe National Statistics Agency 2011
# 11099           Zimbabwe National Statistics Agency 2011
# 11100                                    World Bank 2018
#
#                                   source_comments  \
# 0      National Risk and Vulnerability Assessment
# 1                                       PovcalNet
# 2                                       PovcalNet
# 3                                       PovcalNet
# 4                                       PovcalNet
# ...                                           ...
# 11096                     World Bank. Compilation
# 11097             Zimbabwe Poverty Profile Report
# 11098             Zimbabwe Poverty Profile Report
# 11099             Zimbabwe Poverty Profile Report
# 11100                                   PovcalNet
#
#                                                   survey
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11096         Income, Consumption and Expenditure Survey
# 11097  Poverty Income Consumption and Expenditure Sur...
# 11098  Poverty Income Consumption and Expenditure Sur...
# 11099  Poverty Income Consumption and Expenditure Sur...
# 11100                                                NaN
#
# [11101 rows x 50 columns]

# %%
df.loc[:,'scale']=df['scale'].fillna(df['scale'].mode()[0])
df
# Out:
#           id      country   c3  year  gini_reported    q1     q2     q3  \
# 0          1  Afghanistan  AFG  2008          29.00  9.00  13.00  17.00
# 1          2      Albania  ALB  1996          27.01  9.15  13.70  17.73
# 2          3      Albania  ALB  2002          31.74  8.35  12.58  16.49
# 3          4      Albania  ALB  2005          30.60  8.40  12.90  17.03
# 4          5      Albania  ALB  2008          29.98  8.87  13.07  16.83
# ...      ...          ...  ...   ...            ...   ...    ...    ...
# 11096  11097     Zimbabwe  ZWE  1995          70.30  1.58   3.64   6.34
# 11097  11098     Zimbabwe  ZWE  2011          42.30  6.13  11.00  15.72
# 11098  11099     Zimbabwe  ZWE  2011          37.00  6.13  11.00  15.72
# 11099  11100     Zimbabwe  ZWE  2011          39.00  6.13  11.00  15.72
# 11100  11101     Zimbabwe  ZWE  2011          43.15  5.83   9.50  14.01
#
#           q4     q5  ...  exchangerate  gdp_ppp_pc_usd2011  population  \
# 0      22.00  39.00  ...     50.249615              1298.0  27294031.0
# 1      23.29  36.12  ...    104.498917              4812.0   3092228.0
# 2      22.21  40.37  ...    140.154516              6316.0   3119029.0
# 3      22.50  39.17  ...     99.870254              7563.0   3079179.0
# 4      22.23  39.00  ...     83.894604              9018.0   2991651.0
# ...      ...    ...  ...           ...                 ...         ...
# 11096  11.08  77.36  ...      0.008675              2488.0  11320346.0
# 11097  22.06  44.50  ...           NaN              1667.0  14386649.0
# 11098  22.06  44.50  ...           NaN              1667.0  14386649.0
# 11099  22.06  44.50  ...           NaN              1667.0  14386649.0
# 11100  21.01  49.66  ...           NaN              1667.0  14386649.0
#
#        revision  quality  quality_score                          source  \
# 0      New 2013     High             12  National statistical authority
# 1      New 2018  Average             13                      World Bank
# 2      New 2018  Average             13                      World Bank
# 3      New 2018  Average             13                      World Bank
# 4      New 2018  Average             13                      World Bank
# ...         ...      ...            ...                             ...
# 11096       NaN      Low             13                      World Bank
# 11097  New 2013     High             11  National statistical authority
# 11098  New 2013     High             11  National statistical authority
# 11099  New 2013     High             11  National statistical authority
# 11100  New 2018  Average             13                      World Bank
#
#                                          source_detailed  \
# 0      European Commission and the Government of Afgh...
# 1                                        World Bank 2018
# 2                                        World Bank 2018
# 3                                        World Bank 2018
# 4                                        World Bank 2018
# ...                                                  ...
# 11096              Deininger and Squire, World Bank 2004
# 11097           Zimbabwe National Statistics Agency 2011
# 11098           Zimbabwe National Statistics Agency 2011
# 11099           Zimbabwe National Statistics Agency 2011
# 11100                                    World Bank 2018
#
#                                   source_comments  \
# 0      National Risk and Vulnerability Assessment
# 1                                       PovcalNet
# 2                                       PovcalNet
# 3                                       PovcalNet
# 4                                       PovcalNet
# ...                                           ...
# 11096                     World Bank. Compilation
# 11097             Zimbabwe Poverty Profile Report
# 11098             Zimbabwe Poverty Profile Report
# 11099             Zimbabwe Poverty Profile Report
# 11100                                   PovcalNet
#
#                                                   survey
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11096         Income, Consumption and Expenditure Survey
# 11097  Poverty Income Consumption and Expenditure Sur...
# 11098  Poverty Income Consumption and Expenditure Sur...
# 11099  Poverty Income Consumption and Expenditure Sur...
# 11100                                                NaN
#
# [11101 rows x 50 columns]

# %%
df.loc[:,'scale_detailed']=df['scale_detailed'].fillna(df['scale_detailed'].mode()[0])
df
# Out:
#           id      country   c3  year  gini_reported    q1     q2     q3  \
# 0          1  Afghanistan  AFG  2008          29.00  9.00  13.00  17.00
# 1          2      Albania  ALB  1996          27.01  9.15  13.70  17.73
# 2          3      Albania  ALB  2002          31.74  8.35  12.58  16.49
# 3          4      Albania  ALB  2005          30.60  8.40  12.90  17.03
# 4          5      Albania  ALB  2008          29.98  8.87  13.07  16.83
# ...      ...          ...  ...   ...            ...   ...    ...    ...
# 11096  11097     Zimbabwe  ZWE  1995          70.30  1.58   3.64   6.34
# 11097  11098     Zimbabwe  ZWE  2011          42.30  6.13  11.00  15.72
# 11098  11099     Zimbabwe  ZWE  2011          37.00  6.13  11.00  15.72
# 11099  11100     Zimbabwe  ZWE  2011          39.00  6.13  11.00  15.72
# 11100  11101     Zimbabwe  ZWE  2011          43.15  5.83   9.50  14.01
#
#           q4     q5  ...  exchangerate  gdp_ppp_pc_usd2011  population  \
# 0      22.00  39.00  ...     50.249615              1298.0  27294031.0
# 1      23.29  36.12  ...    104.498917              4812.0   3092228.0
# 2      22.21  40.37  ...    140.154516              6316.0   3119029.0
# 3      22.50  39.17  ...     99.870254              7563.0   3079179.0
# 4      22.23  39.00  ...     83.894604              9018.0   2991651.0
# ...      ...    ...  ...           ...                 ...         ...
# 11096  11.08  77.36  ...      0.008675              2488.0  11320346.0
# 11097  22.06  44.50  ...           NaN              1667.0  14386649.0
# 11098  22.06  44.50  ...           NaN              1667.0  14386649.0
# 11099  22.06  44.50  ...           NaN              1667.0  14386649.0
# 11100  21.01  49.66  ...           NaN              1667.0  14386649.0
#
#        revision  quality  quality_score                          source  \
# 0      New 2013     High             12  National statistical authority
# 1      New 2018  Average             13                      World Bank
# 2      New 2018  Average             13                      World Bank
# 3      New 2018  Average             13                      World Bank
# 4      New 2018  Average             13                      World Bank
# ...         ...      ...            ...                             ...
# 11096       NaN      Low             13                      World Bank
# 11097  New 2013     High             11  National statistical authority
# 11098  New 2013     High             11  National statistical authority
# 11099  New 2013     High             11  National statistical authority
# 11100  New 2018  Average             13                      World Bank
#
#                                          source_detailed  \
# 0      European Commission and the Government of Afgh...
# 1                                        World Bank 2018
# 2                                        World Bank 2018
# 3                                        World Bank 2018
# 4                                        World Bank 2018
# ...                                                  ...
# 11096              Deininger and Squire, World Bank 2004
# 11097           Zimbabwe National Statistics Agency 2011
# 11098           Zimbabwe National Statistics Agency 2011
# 11099           Zimbabwe National Statistics Agency 2011
# 11100                                    World Bank 2018
#
#                                   source_comments  \
# 0      National Risk and Vulnerability Assessment
# 1                                       PovcalNet
# 2                                       PovcalNet
# 3                                       PovcalNet
# 4                                       PovcalNet
# ...                                           ...
# 11096                     World Bank. Compilation
# 11097             Zimbabwe Poverty Profile Report
# 11098             Zimbabwe Poverty Profile Report
# 11099             Zimbabwe Poverty Profile Report
# 11100                                   PovcalNet
#
#                                                   survey
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11096         Income, Consumption and Expenditure Survey
# 11097  Poverty Income Consumption and Expenditure Sur...
# 11098  Poverty Income Consumption and Expenditure Sur...
# 11099  Poverty Income Consumption and Expenditure Sur...
# 11100                                                NaN
#
# [11101 rows x 50 columns]

# %%
df.loc[:,'mean']=df['mean'].fillna(df['mean'].mean())
df.loc[:,'median']=df['median'].fillna(df['median'].mean())

# %%
df.dtypes
# Out:
# id                      int64
# country                object
# c3                     object
# year                    int64
# gini_reported         float64
# q1                    float64
# q2                    float64
# q3                    float64
# q4                    float64
# q5                    float64
# d1                    float64
# d2                    float64
# d3                    float64
# d4                    float64
# d5                    float64
# d6                    float64
# d7                    float64
# d8                    float64
# d9                    float64
# d10                   float64
# resource               object
# resource_detailed      object
# scale                  object
# scale_detailed         object
# sharing_unit           object
# reference_unit         object
# areacovr               object
# areacovr_detailed      object
# popcovr                object
# popcovr_detailed       object
# region_un              object
# region_un_sub          object
# region_wb              object
# eu                     object
# oecd                   object
# incomegroup            object
# mean                  float64
# median                float64
# currency               object
# reference_period       object
# exchangerate          float64
# gdp_ppp_pc_usd2011    float64
# population            float64
# revision               object
# quality                object
# quality_score           int64
# source                 object
# source_detailed        object
# source_comments        object
# survey                 object
# dtype: object

# %%
df.reference_unit.unique()
# Out:
# array(['Person', 'Household', nan, 'Tax unit', 'Family'], dtype=object)

# %%
df['reference_unit'].fillna(df['reference_unit'].mode()[0],inplace=True)

# %%
df['mean'].fillna(df['mean'].median(),inplace=True)
df['median'].fillna(df['median'].median(),inplace=True)

# %%
df.currency.unique()
# Out:
# array(['Afghan afghani', 'US$2011PPP', nan, 'Euro', 'Angolan kwanza',
#        'Argentine peso', 'Local currency unit', 'Argentine austral',
#        'Armenian ruble', 'Armenian dram', 'Australian dollar',
#        'Local currency units, at current prices', 'Austrian schilling',
#        'Azerbaijan ruble', 'Bahamian dollar', 'United States dollar',
#        'Bangladeshi rupee', 'Bangladeshi taka 1973', 'Bangladeshi taka',
#        'Barbadian dollar', 'Belarusian ruble', 'Belarusian ruble (BYB)',
#        'Belarusian ruble (BYB1000)', 'Belgian franc',
#        'Bhutanese ngultrum', 'Bolivian boliviano', 'Botswana pula',
#        'Brazilian cruzeiro', 'United States dollar 1990',
#        'Brazilian real', 'Bulgarian old lev (BGL)', 'Bulgarian lev (BGN)',
#        'CFA franc', 'Cambodian riel', 'Central African CFA franc',
#        'Canadian dollar', 'Canadian dollar  2016', 'Canadian Dollar',
#        'Cape Verdean escudo', 'DMPT', 'Chilean peso', 'Chinese yuan 1986',
#        'Chinese yuan', 'Chinese yuan 1988', 'Chinese yuan 2013',
#        'Colombian peso', 'Costa Rican colon', 'Croatian kuna',
#        'Cuban peso', 'Cypriot pound', 'Crowns', 'Czech koruna',
#        'Czechoslovak koruna', 'Danish krone', 'Djiboutian franc',
#        'Dominican sucre', 'Dominican peso', 'Ecuador sucre',
#        'Egyptian pound 1965', 'Egyptian pound', 'Egyptian pound 1995',
#        'Salvadoran quetzales', 'Estonian ruble', 'Estonian kroon',
#        'Ethopian birr', 'Finnish markka', 'Euro 1999', 'French franc',
#        'Gambian dalasi', 'Georgian ruble', 'Georgian lari',
#        'Deutsche mark', 'Ghanaian cedi', 'Greek drachma',
#        'Guatemalan quetzal', 'Guinean franc', 'Guyanese dollar',
#        'Honduran lempira', 'Hong Kong dollar', 'Hungarian forint',
#        'Icelandic krona', 'Indian rupee 1974', 'Indian rupee',
#        'Indonesian rupiah', 'Iraqi dinar', 'Irish pound', 'Israeli pound',
#        'New Israeli sheqel', 'Italian lira', 'Jamaican dollar',
#        'Japanese yen', 'Jordanian dinar', 'Jordanian dinar 1997',
#        'Kazakhstani ruble', 'Kazakhstani tenge', 'Korean won',
#        'Kyrgyzstani ruble', 'Kyrgyzstani som', 'Latvian ruble',
#        'Latvian lats', 'Lesotho loti', 'Lithuanian ruble',
#        'Lithuanian litas', 'Luxembourg franc', 'Macedonian denar',
#        'Madagascar franc', 'Malagasy ariary', 'Malawian kwacha',
#        'Malayasian dollar', 'Malaysian ringgit', 'Maldivian rufiyaa',
#        'Mauritanian ouguiya', 'Mauritian rupee', 'Mexican peso',
#        'Mexican old Peso', 'Mexican nuevo peso', 'Moldovan ruble',
#        'Moldovan leu', 'Moroccan dirham', 'Mozambican metical',
#        'Mozambican new meticais (millions)', 'Mozambican new metical',
#        'Burmese kyat', 'Namibia dollar', 'Nepalese rupee',
#        'Netherlands guilder', 'New Zealand dollar',
#        'New Zealand dollar 1996', 'Nigerian naira', 'Nigerian naira 1986',
#        'Norwegian krone', 'Pakistani rupee', 'Panamanian balboa',
#        'Paraguayan guarani', 'Peruvian inti', 'Peruvian nuevo sol',
#        'Philippine peso', 'Polish zloty', 'Polish old zloty',
#        'Portuguese escudo 1990', 'Qatari riyal', 'Romanian leu',
#        'Russian ruble', 'Rwandan franc', 'Serbian dinar',
#        'Serbian new dinar', 'Seychellois rupee', 'Sierra Leonean leone',
#        'Singaporean dollar', 'Slovak koruna', 'Slovenian tolar',
#        'South African rand', 'Rubles', 'Spanish peseta',
#        'Sri Lankan rupee', 'Sudanese pound', 'Swedish krona',
#        'Swedish krona 1996', 'Swedish krona 2002', 'Swedish krona 2003',
#        'Swiss franc', 'Syrian pound', 'New Taiwan dollar',
#        'Tajikistani ruble', 'Tanzanian shilling',
#        'Tanzanian shilling 1991', 'Thai baht', 'Thai baht 1975',
#        'Trinidad and Tobago dollar', 'Turkish lira',
#        'Turkmenistani ruble', 'Ugandan shilling', 'Ukrainian ruble',
#        'Ukrainian hryvnia', 'British pound', 'British pound 2002',
#        'British pound 2004', 'United States dollar 2017',
#        'United States dollar 2010', 'Uruguayan peso', 'Uzbekistani ruble',
#        'Uzbekistani sum', 'Venezuelan bolivar', 'Vietnamese dong',
#        'Yugoslavian dinar', 'Zambian kwacha', 'Zimbabwean dollar'],
#       dtype=object)

# %%
df['currency'].fillna("unkown",inplace=True)

# %%
df['reference_period'].fillna("unkown",inplace=True)

# %%
df['exchangerate'].fillna(df['exchangerate'].median(),inplace=True)

# %%
df['gdp_ppp_pc_usd2011'].fillna(df['gdp_ppp_pc_usd2011'].median(),inplace=True)
df
# Out:
#           id      country   c3  year  gini_reported    q1     q2     q3  \
# 0          1  Afghanistan  AFG  2008          29.00  9.00  13.00  17.00
# 1          2      Albania  ALB  1996          27.01  9.15  13.70  17.73
# 2          3      Albania  ALB  2002          31.74  8.35  12.58  16.49
# 3          4      Albania  ALB  2005          30.60  8.40  12.90  17.03
# 4          5      Albania  ALB  2008          29.98  8.87  13.07  16.83
# ...      ...          ...  ...   ...            ...   ...    ...    ...
# 11096  11097     Zimbabwe  ZWE  1995          70.30  1.58   3.64   6.34
# 11097  11098     Zimbabwe  ZWE  2011          42.30  6.13  11.00  15.72
# 11098  11099     Zimbabwe  ZWE  2011          37.00  6.13  11.00  15.72
# 11099  11100     Zimbabwe  ZWE  2011          39.00  6.13  11.00  15.72
# 11100  11101     Zimbabwe  ZWE  2011          43.15  5.83   9.50  14.01
#
#           q4     q5  ...  exchangerate  gdp_ppp_pc_usd2011  population  \
# 0      22.00  39.00  ...     50.249615              1298.0  27294031.0
# 1      23.29  36.12  ...    104.498917              4812.0   3092228.0
# 2      22.21  40.37  ...    140.154516              6316.0   3119029.0
# 3      22.50  39.17  ...     99.870254              7563.0   3079179.0
# 4      22.23  39.00  ...     83.894604              9018.0   2991651.0
# ...      ...    ...  ...           ...                 ...         ...
# 11096  11.08  77.36  ...      0.008675              2488.0  11320346.0
# 11097  22.06  44.50  ...      3.657642              1667.0  14386649.0
# 11098  22.06  44.50  ...      3.657642              1667.0  14386649.0
# 11099  22.06  44.50  ...      3.657642              1667.0  14386649.0
# 11100  21.01  49.66  ...      3.657642              1667.0  14386649.0
#
#        revision  quality  quality_score                          source  \
# 0      New 2013     High             12  National statistical authority
# 1      New 2018  Average             13                      World Bank
# 2      New 2018  Average             13                      World Bank
# 3      New 2018  Average             13                      World Bank
# 4      New 2018  Average             13                      World Bank
# ...         ...      ...            ...                             ...
# 11096       NaN      Low             13                      World Bank
# 11097  New 2013     High             11  National statistical authority
# 11098  New 2013     High             11  National statistical authority
# 11099  New 2013     High             11  National statistical authority
# 11100  New 2018  Average             13                      World Bank
#
#                                          source_detailed  \
# 0      European Commission and the Government of Afgh...
# 1                                        World Bank 2018
# 2                                        World Bank 2018
# 3                                        World Bank 2018
# 4                                        World Bank 2018
# ...                                                  ...
# 11096              Deininger and Squire, World Bank 2004
# 11097           Zimbabwe National Statistics Agency 2011
# 11098           Zimbabwe National Statistics Agency 2011
# 11099           Zimbabwe National Statistics Agency 2011
# 11100                                    World Bank 2018
#
#                                   source_comments  \
# 0      National Risk and Vulnerability Assessment
# 1                                       PovcalNet
# 2                                       PovcalNet
# 3                                       PovcalNet
# 4                                       PovcalNet
# ...                                           ...
# 11096                     World Bank. Compilation
# 11097             Zimbabwe Poverty Profile Report
# 11098             Zimbabwe Poverty Profile Report
# 11099             Zimbabwe Poverty Profile Report
# 11100                                   PovcalNet
#
#                                                   survey
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 11096         Income, Consumption and Expenditure Survey
# 11097  Poverty Income Consumption and Expenditure Sur...
# 11098  Poverty Income Consumption and Expenditure Sur...
# 11099  Poverty Income Consumption and Expenditure Sur...
# 11100                                                NaN
#
# [11101 rows x 50 columns]

# %%
df['population'].fillna(df['population'].median(), inplace=True)
df['revision'].fillna("unknown",inplace=True)
df['source_comments'].fillna("No comments", inplace=True)
df['resource'].fillna("Unknown", inplace=True)

# %% [markdown]
# # How is income inequality distributed across different countries?

# %%
country_gini = df.groupby('country')['gini_reported'].mean().reset_index()

# %%
sb.histplot(country_gini['gini_reported'], bins=30, kde=True,color='Teal')
plt.title("Distribution of Income Inequality Across Countries")
plt.xlabel("Average Gini Coefficient")
plt.ylabel("Number of Countries")
plt.figure(figsize=(15,5))
plt.show()

# %% [markdown]
# # which countries show the highest and lowest inequality levels?

# %%
top10= country_gini.sort_values(by='gini_reported',ascending=False).head(10)
plt.figure(figsize=(18,5))
plt.subplot(1,2,1)
sb.barplot(x=top10.country, y=top10.gini_reported,palette="BrBG",edgecolor='black')
plt.title("Top 10 Countries with Highest Inequality")
plt.xlabel("Gini Coefficient")
plt.ylabel("Country")
plt.xticks(rotation=45)

bottom10 = country_gini.sort_values(by='gini_reported').head(10)

plt.subplot(1,2,2)
sb.barplot(x=bottom10.country, y=bottom10.gini_reported,palette="BrBG",edgecolor='black')
plt.title(" Top 10 Countries with Lowest Inequality")
plt.xlabel("Gini Coefficient")
plt.ylabel("Country")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # How does the distribution gini coefficient vary globally?

# %%
sb.histplot(df['gini_reported'], bins=30, kde=True,color='Teal')
plt.title("Global Distribution of Gini Coefficient")
plt.xlabel("Gini Coefficient")
plt.ylabel("Frequency")
plt.figure(figsize=(16,5))
plt.show()

# %% [markdown]
# # regional inequality distribution

# %% [markdown]
# ## how does income inequalinty vary across different region?

# %%
region_avg = df.groupby('region_un')['gini_reported'].mean().reset_index().sort_values(by='gini_reported', ascending=False)


sb.barplot(x=region_avg.gini_reported, y=region_avg.region_un,palette="BrBG",edgecolor='black')
plt.title("Average Income Inequality Across Regions")
plt.xlabel("Average Gini Coefficient")
plt.ylabel("Region")
plt.figure(figsize=(10,5))
plt.show()

# %% [markdown]
# # which regions have the highest average inequality levels?

# %%
highest_region = region_avg.iloc[0]
print("Highest Inequality Region:\n", highest_region)
# Out:
# Highest Inequality Region:
#  region_un         Africa
# gini_reported    47.3775
# Name: 0, dtype: object

# %% [markdown]
# # which regions show the lowest inequality levels?

# %%
lowest_region = region_avg.iloc[-1]
print("Lowest Inequality Region:\n", lowest_region)
# Out:
# Lowest Inequality Region:
#  region_un           Europe
# gini_reported    31.910684
# Name: 3, dtype: object

# %% [markdown]
# # Are there noticeable region patterns in income distribution?

# %%
sb.boxplot(x=df.region_un, y=df.gini_reported,palette="BrBG")
plt.title("Distribution of Inequality Across Regions")
plt.xlabel("Region")
plt.ylabel("Gini Coefficient")
plt.figure(figsize=(15,7))
plt.show()

# %% [markdown]
# # Ecomic development vs inequailty

# %% [markdown]
# ## Is there any relationship between GDP per capita and income inequality?

# %%
sb.scatterplot(x=df.gdp_ppp_pc_usd2011,y=df.gini_reported,color='Teal',edgecolor='black')
plt.title("GDP per Capita vs Income Inequality")
plt.xlabel("GDP per Capita (PPP USD 2011)")
plt.ylabel("Gini Coefficient")
plt.show()

# %% [markdown]
# ## Do countries with higher GDP tend to have lower inequality?

# %% [markdown]
# ### countries with higher GDP per capita do not always have lower income inequality while some high income country exhibit more equal income distribution there are several expections where wealthy nature still experience significant inequailty.overall the relationship between GDP and inequality is weak and not strickly negative.

# %% [markdown]
# ## income group distribution

# %% [markdown]
# ## how does ineqality differ between low-income,middle-income and hingh-income countries?

# %%
income_avg = df.groupby('incomegroup')['gini_reported'].mean().reset_index().sort_values(by='gini_reported', ascending=False)

plt.figure(figsize=(12,5))
sb.barplot(x=income_avg.incomegroup, y=income_avg.gini_reported,palette="BrBG",edgecolor='black')
plt.title("Inequality Comparison Across Income Groups")
plt.xlabel("Income Group")
plt.ylabel("Average Gini Coefficient")
plt.show()

# %% [markdown]
# ## which income group shows the greatest inequality varition?

# %%
variation = df.groupby('incomegroup')['gini_reported'].std().reset_index().sort_values(by='gini_reported', ascending=False)

highest_variation = variation.iloc[0]

print("Income group with highest inequality variation:\n")
print(highest_variation)
# Out:
# Income group with highest inequality variation:
#
# incomegroup      Upper middle income
# gini_reported              10.796899
# Name: 3, dtype: object

# %% [markdown]
# ## Do welthier nations consistently maintain lower inequality levels?

# %%
plt.figure(figsize=(12,5))
sb.boxplot(x=df.incomegroup, y=df.gini_reported,palette="BrBG")
plt.title("Inequality Across Income Groups")
plt.xlabel("Income Group")
plt.ylabel("Gini Coefficient")
plt.show()

# %% [markdown]
# ## how stable are inequality levels across diffferent income groups?

# %% [markdown]
# ### Inequality levels are more stable in high income countries,while low income and middle income countries exhibit greater varaibility and less stability in income distrinution.This indicate that developed economies tend to maintian more consistance equality levels over time.

# %% [markdown]
# ## country levels inequality analysis

# %% [markdown]
# ### which countries consistenly show high inequality levels?

# %%
country_std = df.groupby('country')['gini_reported'].std().reset_index()

country_stats = pd.merge(country_gini, country_std, on='country')
country_stats.columns = ['country', 'avg_gini', 'std_gini']

high_inequality = country_stats[(country_stats['avg_gini'] > 45) & (country_stats['std_gini'] < 5)]
high_inequality = high_inequality.sort_values(by='avg_gini', ascending=False)

top_countries = high_inequality.head(10)

plt.figure(figsize=(10,5))
sb.barplot(x=top_countries.avg_gini, y=top_countries.country,palette="BrBG",edgecolor='black')
plt.title("Countries with Consistently High Inequality")
plt.xlabel("Average Gini Coefficient")
plt.ylabel("Country")
plt.show()

# %% [markdown]
# ## which country demonstrate more equal income distribution?

# %%
equal_countries = country_gini.sort_values(by='gini_reported').head(10)

plt.figure(figsize=(10,4))
plt.scatter(equal_countries['gini_reported'], equal_countries['country'],color='Teal',edgecolor='black')
plt.title("Top 10 Countries with Most Equal Income Distribution")
plt.xlabel("Gini Coefficient")
plt.ylabel("Country")
plt.show()

# %% [markdown]
# ## are there countries where inequality flutuates significantly over time?

# %%
country_fluctuation = df.groupby('country')['gini_reported'].std().reset_index().sort_values(by='gini_reported', ascending=False)

top_fluctuating = country_fluctuation.head(5)['country']

fluct_data = df[df['country'].isin(top_fluctuating)]

plt.figure(figsize=(12,5))
sb.lineplot(x=fluct_data.year, y=fluct_data.gini_reported, hue=fluct_data.country,marker='x',markeredgecolor='black',palette="BrBG")
plt.title("Countries with High Inequality Fluctuations Over Time")
plt.xlabel("Year")
plt.ylabel("Gini Coefficient")
plt.legend(title='Country',bbox_to_anchor=(1.17,1.0))
plt.grid(True)
plt.show()

# %% [markdown]
# ## what economic or regional factors might explian these patterns?

# %% [markdown]
# ### population and inequality trend analysis

# %% [markdown]
# ## how has income inequality changed over time globally?

# %%
global_trend = df.groupby('year')['gini_reported'].mean().reset_index()

plt.figure(figsize=(12,5))
sb.lineplot(x=global_trend.year, y=global_trend.gini_reported,marker='x',markeredgecolor='black',color='Teal')
plt.title("Global Income Inequality Trend Over Time")
plt.xlabel("Year")
plt.ylabel("Average Gini Coefficient")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Are these periods where inequality increased or decreased significantly?

# %% [markdown]
# ### Is there are any relationship between a country's popluation size and inequality level?

# %%
sb.scatterplot(x=df.population,y=df.gini_reported,color='Teal',edgecolor='black')
plt.title("Population vs Income Inequality")
plt.xlabel("Population")
plt.ylabel("Gini Coefficient")
plt.figure(figsize=(12,6))
plt.show()

# %% [markdown]
# ## Do high populted countries tend to have higher inequality ?

# %% [markdown]
# ### Highly popluted countries do not necessary  tend to have higher income inequality. The analysis shows no consistance relation between population szie and inequality levels.
